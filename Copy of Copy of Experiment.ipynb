# %%
from datetime import date, datetime as dt, timedelta as td
import pytz
import time
import pandas as pd
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, SimpleRNN
import warnings
warnings.filterwarnings("ignore")

from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import ConvLSTM2D
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.utils import to_categorical
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing functions

# %%
PATH = 'drive/MyDrive/Colab Notebooks/StepCount.csv'
early_stopping_cb = EarlyStopping(patience=5, min_delta=0.000003, restore_best_weights=True)
data = pd.read_csv(PATH)

# %%
def convert_steps(steps, grouping=['date']):
  convert_tz = lambda x: x.to_pydatetime().replace(tzinfo=pytz.utc).astimezone(pytz.timezone('Europe/Vilnius'))
  get_year = lambda x: convert_tz(x).year
  get_month = lambda x: '{}-{:02}'.format(convert_tz(x).year, convert_tz(x).month) #inefficient
  get_date = lambda x: '{}-{:02}-{:02}'.format(convert_tz(x).year, convert_tz(x).month, convert_tz(x).day) #inefficient
  get_day = lambda x: convert_tz(x).day
  get_hour = lambda x: convert_tz(x).hour
  get_minute = lambda x: convert_tz(x).minute
  get_day_of_week = lambda x: convert_tz(x).weekday()


  steps['startDate'] = pd.to_datetime(steps['startDate'])
  steps['year'] = steps['startDate'].map(get_year)
  steps['month'] = steps['startDate'].map(get_month)
  steps['date'] = steps['startDate'].map(get_date)
  steps['day'] = steps['startDate'].map(get_day)
  steps['hour'] = steps['startDate'].map(get_hour)
  steps['dow'] = steps['startDate'].map(get_day_of_week)

  corona_start = steps[steps.date == "2020-03-10"].index[0]
  steps = steps.iloc[:corona_start, :]

  return steps.groupby(grouping)['value'].sum().reset_index(name='Steps')


def prepare_sequence(sequence, n_previous, n_future):
    """
    Input: 
        - sequence: numpy array, pandas DataFrame or list; input sequence
        - n_previous: int; number of past data points (N)
        - n_future: int; number of data points to be predicted (K)
    Returns:
        - X: (seq. length x n_previous) numpy array with the previous observations
        - y: (seq. length x n_fututre) numpy array with the target observations
    """
    
    X, y = [], []
    idx, i = 0, 0
    while idx+n_future <= len(sequence)-1:
        idx = i + n_previous
        X.append(sequence[i:idx])
        y.append(sequence[idx:idx+n_future])
        i += 1
        
    return np.array(X), np.array(y)


def season(month):
    if month in [12, 1, 2]:
        return 0
    elif month in [3, 4, 5]:
        return 1
    elif month in [6, 7, 8]:
        return 2
    elif month in [9, 10, 11]:
        return 3


def augment(steps):
    augmented = steps.groupby(['date'])['value'].sum().reset_index(name='Steps')
    dow = steps.groupby(['date']).mean()['dow']
    augmented['dow'] = (dow.apply(int)).to_list()
    month = augmented.date.apply(lambda a: int(a.split('-')[1]))
    augmented['season'] = month.apply(season)
    
    return augmented

# %% [markdown]
# # Load and prepare the data

# %%
steps_by_date = convert_steps(data)
steps_by_date_hour = convert_steps(data, ['date', 'hour'])

# Remove an invalid day
#steps_by_date = steps_by_date.iloc#[:-1]

# Replace the unrealistic values with the median
steps_by_date.Steps[steps_by_date.Steps < 300] = steps_by_date.Steps.median()

# Augent the data
augmented_steps_by_date = augment(data)

# %%
results = pd.DataFrame(columns=["Model", "N_K", "MAE", "RMSE", "Error_Steps"])

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Baseline

# %%
def average(history, n, k):
  if k == 1:
    return np.mean(history[-n:])
  else:
    predictions = []
    while k != 0:
      prediction = np.mean(history[-n:])
      predictions.append(prediction)
      np.append(history, prediction)
      k -= 1
    return predictions

# %%
configurations = [(steps_by_date, 7, 1), (steps_by_date, 14, 1), (steps_by_date_hour, 24, 1),
                  (steps_by_date_hour, 24, 6), (steps_by_date_hour, 24, 12), (steps_by_date_hour, 48, 24)]
row = 0


for c in configurations:

  # Split to training and test
  coef = 0.1
  split_size = int(len(c[0].Steps) * (1 - coef))
  train_data, test_data = c[0].Steps[:split_size], c[0].Steps[split_size:]

  # Normalize the data
  scaler = MinMaxScaler() 
  norm_train = scaler.fit_transform(train_data.to_numpy().reshape(-1, 1))
  norm_test = scaler.transform(test_data.to_numpy().reshape(-1, 1))

  # Prepare
  X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1], c[2])
  X_test, y_test = prepare_sequence(norm_test, c[1], c[2])

  history = X_train.flatten()

  # Predict
  baseline_predictions = list()
  for t in range(len(y_test)):
      baseline_predictions.append(average(history, c[1], c[2]))
      np.append(history, y_test.squeeze()[t])
 
  rmse = sqrt(mean_squared_error(y_test.squeeze(), baseline_predictions))
  mae = mean_absolute_error(y_test.squeeze(), baseline_predictions)
  error_steps = scaler.inverse_transform(np.array(mae).reshape(1, -1))

  results.loc[row] = ["Baseline", "{}_{}".format(c[1], c[2]), mae, rmse, error_steps[0][0]]
  row += 1

# %%
results
# Out:
#       Model    N_K       MAE      RMSE  Error_Steps
# 0  Baseline    7_1  0.109887  0.133907  3545.951198
# 1  Baseline   14_1  0.116042  0.140325  3727.770872
# 2  Baseline   24_1  0.073331  0.094649   620.280473
# 3  Baseline   24_6  0.073325  0.094685   620.230618
# 4  Baseline  24_12  0.073338  0.094732   620.342998
# 5  Baseline  48_24  0.072413  0.095002   612.531287

# %% [markdown]
# ## LSTM

# %%
def vanilla_LSTM(output_size, n_timestamps, n_features, next_predicted=1):
  model = Sequential()
  model.add(LSTM(output_size, input_shape=(n_timestamps, n_features), activation='tanh'))
  model.add(Dense(next_predicted))
  model.compile(optimizer='adam', loss='mse', metrics=['mean_absolute_error'])
  return model

# %%
for c in configurations:
  # Split to training and test
  coef = 0.1
  split_size = int(len(c[0].Steps) * (1 - coef))
  train_data, test_data = c[0].Steps[:split_size], c[0].Steps[split_size:]

  # Normalize the data
  scaler = MinMaxScaler() 
  norm_train = scaler.fit_transform(train_data.to_numpy().reshape(-1, 1))
  norm_test = scaler.transform(test_data.to_numpy().reshape(-1, 1))

  # Prepare
  X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1], c[2])
  X_test, y_test = prepare_sequence(norm_test, c[1], c[2])

  X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


  # Build model
  single_model = vanilla_LSTM(1, X_train.shape[1], X_train.shape[2], c[2])
  # Fit the model
  history = single_model.fit(X_train, y_train, epochs=300, validation_split=0.1, shuffle=False, batch_size=6, callbacks=[early_stopping_cb])

  # Predict
  single_predictions = single_model.predict(X_test)

  rmse = sqrt(mean_squared_error(y_test.squeeze(), single_predictions))
  mae = mean_absolute_error(y_test.squeeze(), single_predictions)
  error_steps = scaler.inverse_transform(np.array(mae).reshape(1, -1))

  results.loc[row] = ["Vanilla LSTM", "{}_{}".format(c[1], c[2]), mae, rmse, error_steps[0][0]]

  row += 1
# Out:
# Epoch 1/300
# 225/225 [==============================] - 32s 7ms/step - loss: 0.0867 - mean_absolute_error: 0.2245 - val_loss: 0.0169 - val_mean_absolute_error: 0.1066
# Epoch 2/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0385 - mean_absolute_error: 0.1492 - val_loss: 0.0166 - val_mean_absolute_error: 0.1047
# Epoch 3/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0380 - mean_absolute_error: 0.1486 - val_loss: 0.0165 - val_mean_absolute_error: 0.1034
# Epoch 4/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0374 - mean_absolute_error: 0.1478 - val_loss: 0.0164 - val_mean_absolute_error: 0.1024
# Epoch 5/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0368 - mean_absolute_error: 0.1469 - val_loss: 0.0163 - val_mean_absolute_error: 0.1015
# Epoch 6/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0362 - mean_absolute_error: 0.1461 - val_loss: 0.0163 - val_mean_absolute_error: 0.1008
# Epoch 7/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0358 - mean_absolute_error: 0.1454 - val_loss: 0.0162 - val_mean_absolute_error: 0.1003
# Epoch 8/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0354 - mean_absolute_error: 0.1448 - val_loss: 0.0162 - val_mean_absolute_error: 0.0999
# Epoch 9/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0351 - mean_absolute_error: 0.1444 - val_loss: 0.0162 - val_mean_absolute_error: 0.0995
# Epoch 10/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0348 - mean_absolute_error: 0.1440 - val_loss: 0.0162 - val_mean_absolute_error: 0.0993
# Epoch 11/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0346 - mean_absolute_error: 0.1436 - val_loss: 0.0162 - val_mean_absolute_error: 0.0990
# Epoch 12/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0345 - mean_absolute_error: 0.1434 - val_loss: 0.0162 - val_mean_absolute_error: 0.0989
# Epoch 13/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0344 - mean_absolute_error: 0.1431 - val_loss: 0.0162 - val_mean_absolute_error: 0.0987
# Epoch 14/300
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0343 - mean_absolute_error: 0.1430 - val_loss: 0.0162 - val_mean_absolute_error: 0.0986
# Epoch 1/300
# 224/224 [==============================] - 3s 7ms/step - loss: 0.1202 - mean_absolute_error: 0.2860 - val_loss: 0.0181 - val_mean_absolute_error: 0.1066
# Epoch 2/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0404 - mean_absolute_error: 0.1499 - val_loss: 0.0179 - val_mean_absolute_error: 0.1130
# Epoch 3/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0343 - mean_absolute_error: 0.1422 - val_loss: 0.0178 - val_mean_absolute_error: 0.1121
# Epoch 4/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0340 - mean_absolute_error: 0.1418 - val_loss: 0.0175 - val_mean_absolute_error: 0.1110
# Epoch 5/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0338 - mean_absolute_error: 0.1415 - val_loss: 0.0173 - val_mean_absolute_error: 0.1100
# Epoch 6/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0337 - mean_absolute_error: 0.1412 - val_loss: 0.0172 - val_mean_absolute_error: 0.1092
# Epoch 7/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0335 - mean_absolute_error: 0.1409 - val_loss: 0.0170 - val_mean_absolute_error: 0.1085
# Epoch 8/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0333 - mean_absolute_error: 0.1406 - val_loss: 0.0169 - val_mean_absolute_error: 0.1078
# Epoch 9/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0331 - mean_absolute_error: 0.1404 - val_loss: 0.0167 - val_mean_absolute_error: 0.1070
# Epoch 10/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0330 - mean_absolute_error: 0.1401 - val_loss: 0.0166 - val_mean_absolute_error: 0.1063
# Epoch 11/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0328 - mean_absolute_error: 0.1398 - val_loss: 0.0165 - val_mean_absolute_error: 0.1056
# Epoch 12/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0326 - mean_absolute_error: 0.1395 - val_loss: 0.0164 - val_mean_absolute_error: 0.1049
# Epoch 13/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0325 - mean_absolute_error: 0.1392 - val_loss: 0.0163 - val_mean_absolute_error: 0.1041
# Epoch 14/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0323 - mean_absolute_error: 0.1389 - val_loss: 0.0162 - val_mean_absolute_error: 0.1034
# Epoch 15/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0321 - mean_absolute_error: 0.1386 - val_loss: 0.0161 - val_mean_absolute_error: 0.1026
# Epoch 16/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0319 - mean_absolute_error: 0.1382 - val_loss: 0.0161 - val_mean_absolute_error: 0.1020
# Epoch 17/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0318 - mean_absolute_error: 0.1379 - val_loss: 0.0160 - val_mean_absolute_error: 0.1014
# Epoch 18/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0316 - mean_absolute_error: 0.1376 - val_loss: 0.0160 - val_mean_absolute_error: 0.1009
# Epoch 19/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0314 - mean_absolute_error: 0.1374 - val_loss: 0.0159 - val_mean_absolute_error: 0.1004
# Epoch 20/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0313 - mean_absolute_error: 0.1371 - val_loss: 0.0159 - val_mean_absolute_error: 0.0999
# Epoch 21/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0311 - mean_absolute_error: 0.1369 - val_loss: 0.0159 - val_mean_absolute_error: 0.0995
# Epoch 22/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0310 - mean_absolute_error: 0.1367 - val_loss: 0.0158 - val_mean_absolute_error: 0.0991
# Epoch 23/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0308 - mean_absolute_error: 0.1365 - val_loss: 0.0158 - val_mean_absolute_error: 0.0988
# Epoch 24/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0307 - mean_absolute_error: 0.1363 - val_loss: 0.0158 - val_mean_absolute_error: 0.0985
# Epoch 25/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0306 - mean_absolute_error: 0.1361 - val_loss: 0.0158 - val_mean_absolute_error: 0.0982
# Epoch 26/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0306 - mean_absolute_error: 0.1360 - val_loss: 0.0158 - val_mean_absolute_error: 0.0980
# Epoch 27/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0305 - mean_absolute_error: 0.1358 - val_loss: 0.0158 - val_mean_absolute_error: 0.0978
# Epoch 28/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0304 - mean_absolute_error: 0.1357 - val_loss: 0.0158 - val_mean_absolute_error: 0.0977
# Epoch 29/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0304 - mean_absolute_error: 0.1356 - val_loss: 0.0158 - val_mean_absolute_error: 0.0975
# Epoch 30/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0304 - mean_absolute_error: 0.1355 - val_loss: 0.0158 - val_mean_absolute_error: 0.0974
# Epoch 31/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0303 - mean_absolute_error: 0.1354 - val_loss: 0.0158 - val_mean_absolute_error: 0.0973
# Epoch 32/300
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0303 - mean_absolute_error: 0.1354 - val_loss: 0.0158 - val_mean_absolute_error: 0.0973
# Epoch 1/300
# 2742/2742 [==============================] - 18s 6ms/step - loss: 0.0327 - mean_absolute_error: 0.1237 - val_loss: 0.0089 - val_mean_absolute_error: 0.0707
# Epoch 2/300
# 2742/2742 [==============================] - 15s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0829 - val_loss: 0.0079 - val_mean_absolute_error: 0.0667
# Epoch 3/300
# 2742/2742 [==============================] - 15s 6ms/step - loss: 0.0106 - mean_absolute_error: 0.0772 - val_loss: 0.0076 - val_mean_absolute_error: 0.0651
# Epoch 4/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0745 - val_loss: 0.0076 - val_mean_absolute_error: 0.0648
# Epoch 5/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0738 - val_loss: 0.0076 - val_mean_absolute_error: 0.0648
# Epoch 6/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0737 - val_loss: 0.0076 - val_mean_absolute_error: 0.0647
# Epoch 7/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0736 - val_loss: 0.0076 - val_mean_absolute_error: 0.0647
# Epoch 8/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0735 - val_loss: 0.0076 - val_mean_absolute_error: 0.0647
# Epoch 9/300
# 2742/2742 [==============================] - 15s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0735 - val_loss: 0.0076 - val_mean_absolute_error: 0.0647
# Epoch 1/300
# 2742/2742 [==============================] - 18s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0785 - val_loss: 0.0079 - val_mean_absolute_error: 0.0667
# Epoch 2/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0779 - val_loss: 0.0079 - val_mean_absolute_error: 0.0666
# Epoch 3/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0777 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 4/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0776 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 5/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0775 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 6/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0775 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 7/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0774 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 8/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0774 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 9/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0774 - val_loss: 0.0078 - val_mean_absolute_error: 0.0665
# Epoch 1/300
# 2742/2742 [==============================] - 18s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0795 - val_loss: 0.0079 - val_mean_absolute_error: 0.0671
# Epoch 2/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0787 - val_loss: 0.0079 - val_mean_absolute_error: 0.0671
# Epoch 3/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0786 - val_loss: 0.0079 - val_mean_absolute_error: 0.0669
# Epoch 4/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0783 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 5/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0781 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 6/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0781 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 7/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0780 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 8/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0780 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 9/300
# 2742/2742 [==============================] - 16s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0780 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 10/300
# 2742/2742 [==============================] - 15s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0780 - val_loss: 0.0079 - val_mean_absolute_error: 0.0668
# Epoch 1/300
# 2738/2738 [==============================] - 25s 9ms/step - loss: 0.0124 - mean_absolute_error: 0.0799 - val_loss: 0.0079 - val_mean_absolute_error: 0.0670
# Epoch 2/300
# 2738/2738 [==============================] - 24s 9ms/step - loss: 0.0111 - mean_absolute_error: 0.0787 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 3/300
# 2738/2738 [==============================] - 23s 9ms/step - loss: 0.0111 - mean_absolute_error: 0.0786 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 4/300
# 2738/2738 [==============================] - 24s 9ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 5/300
# 2738/2738 [==============================] - 23s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 6/300
# 2738/2738 [==============================] - 23s 9ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 7/300
# 2738/2738 [==============================] - 23s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 8/300
# 2738/2738 [==============================] - 23s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 9/300
# 2738/2738 [==============================] - 23s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669
# Epoch 10/300
# 2738/2738 [==============================] - 23s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0785 - val_loss: 0.0078 - val_mean_absolute_error: 0.0669

# %%
results
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 0       Baseline    7_1  0.109887  0.133907  3545.951198
# 1       Baseline   14_1  0.116042  0.140325  3727.770872
# 2       Baseline   24_1  0.073331  0.094649   620.280473
# 3       Baseline   24_6  0.073325  0.094685   620.230618
# 4       Baseline  24_12  0.073338  0.094732   620.342998
# 5       Baseline  48_24  0.072413  0.095002   612.531287
# 6   Vanilla LSTM    7_1  0.084535  0.112442  2797.085491
# 7   Vanilla LSTM   14_1  0.085292  0.113620  2819.435088
# 8   Vanilla LSTM   24_1  0.072876  0.096130   616.441556
# 9   Vanilla LSTM   24_6  0.072069  0.095411   609.624564
# 10  Vanilla LSTM  24_12  0.072000  0.095288   609.040175
# 11  Vanilla LSTM  48_24  0.071857  0.095206   607.835647

# %% [markdown]
# ## BLSTM

# %%
def BLSTM(output_size, n_timestamps, n_features, next_predicted=1):
  model = Sequential()
  model.add(Bidirectional(LSTM(output_size, activation='tanh'), input_shape=(n_timestamps, n_features)))
  model.add(Dense(next_predicted))
  model.compile(optimizer='adam', loss='mse')
  return model

# %%
for c in configurations:
  # Split to training and test
  coef = 0.1
  split_size = int(len(c[0].Steps) * (1 - coef))
  train_data, test_data = c[0].Steps[:split_size], c[0].Steps[split_size:]

  # Normalize the data
  scaler = MinMaxScaler() 
  norm_train = scaler.fit_transform(train_data.to_numpy().reshape(-1, 1))
  norm_test = scaler.transform(test_data.to_numpy().reshape(-1, 1))

  # Prepare
  X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1], c[2])
  X_test, y_test = prepare_sequence(norm_test, c[1], c[2])

  X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

  # Build model
  single_model = BLSTM(1, X_train.shape[1], X_train.shape[2], c[2])
  # Fit the model
  history = single_model.fit(X_train, y_train, epochs=300, validation_split=0.1, shuffle=False, batch_size=6, callbacks=[early_stopping_cb])

  # Predict
  single_predictions = single_model.predict(X_test)

  rmse = sqrt(mean_squared_error(y_test.squeeze(), single_predictions))
  mae = mean_absolute_error(y_test.squeeze(), single_predictions)
  error_steps = scaler.inverse_transform(np.array(mae).reshape(1, -1))

  results.loc[row] = ["BLSTM", "{}_{}".format(c[1], c[2]), mae, rmse, error_steps[0][0]]

  row += 1
# Out:
# Epoch 1/300
# 225/225 [==============================] - 6s 10ms/step - loss: 0.0650 - val_loss: 0.0168
# Epoch 2/300
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0387 - val_loss: 0.0168
# Epoch 3/300
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0373 - val_loss: 0.0166
# Epoch 4/300
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0366 - val_loss: 0.0166
# Epoch 5/300
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0360 - val_loss: 0.0167
# Epoch 6/300
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0355 - val_loss: 0.0168
# Epoch 7/300
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0352 - val_loss: 0.0169
# Epoch 8/300
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0351 - val_loss: 0.0169
# Epoch 1/300
# 224/224 [==============================] - 6s 13ms/step - loss: 0.0298 - val_loss: 0.0158
# Epoch 2/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 3/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 4/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 5/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 6/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 7/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 8/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 9/300
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0297 - val_loss: 0.0158
# Epoch 1/300
# 2742/2742 [==============================] - 31s 10ms/step - loss: 0.0117 - val_loss: 0.0076
# Epoch 2/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0102 - val_loss: 0.0076
# Epoch 3/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0101 - val_loss: 0.0076
# Epoch 4/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0100 - val_loss: 0.0076
# Epoch 5/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 6/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 7/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 8/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 9/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 1/300
# 2742/2742 [==============================] - 31s 10ms/step - loss: 0.0141 - val_loss: 0.0080
# Epoch 2/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 3/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 4/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 5/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 6/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 7/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 8/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 9/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 10/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 1/300
# 2742/2742 [==============================] - 30s 10ms/step - loss: 0.0134 - val_loss: 0.0079
# Epoch 2/300
# 2742/2742 [==============================] - 26s 9ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 3/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 4/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 5/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 6/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 7/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 8/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 9/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 10/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 11/300
# 2742/2742 [==============================] - 26s 10ms/step - loss: 0.0109 - val_loss: 0.0078
# Epoch 1/300
# 2738/2738 [==============================] - 48s 16ms/step - loss: 0.0125 - val_loss: 0.0079
# Epoch 2/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 3/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 4/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 5/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 6/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 7/300
# 2738/2738 [==============================] - 45s 16ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 8/300
# 2738/2738 [==============================] - 44s 16ms/step - loss: 0.0110 - val_loss: 0.0078

# %%
results
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 0       Baseline    7_1  0.109887  0.133907  3545.951198
# 1       Baseline   14_1  0.116042  0.140325  3727.770872
# 2       Baseline   24_1  0.073331  0.094649   620.280473
# 3       Baseline   24_6  0.073325  0.094685   620.230618
# 4       Baseline  24_12  0.073338  0.094732   620.342998
# 5       Baseline  48_24  0.072413  0.095002   612.531287
# 6   Vanilla LSTM    7_1  0.084535  0.112442  2797.085491
# 7   Vanilla LSTM   14_1  0.085292  0.113620  2819.435088
# 8   Vanilla LSTM   24_1  0.072876  0.096130   616.441556
# 9   Vanilla LSTM   24_6  0.072069  0.095411   609.624564
# 10  Vanilla LSTM  24_12  0.072000  0.095288   609.040175
# 11  Vanilla LSTM  48_24  0.071857  0.095206   607.835647
# 12         BLSTM    7_1  0.085940  0.112182  2838.575706
# 13         BLSTM   14_1  0.085001  0.113605  2810.856383
# 14         BLSTM   24_1  0.072937  0.096107   616.956640
# 15         BLSTM   24_6  0.072127  0.095207   610.115911
# 16         BLSTM  24_12  0.072052  0.095196   609.483145
# 17         BLSTM  48_24  0.071808  0.095233   607.421864

# %% [markdown]
# ## Simple RNN

# %%
def simple_RNN(output_size, n_timestamps, n_features, next_predicted=1):
  model = Sequential()
  model.add(SimpleRNN(output_size, activation='relu', input_shape=(n_timestamps, n_features)))
  model.add(Dense(next_predicted))
  model.compile(optimizer='adam', loss='mse')

  return model

# %%
for c in configurations:
  # Split to training and test
  coef = 0.1
  split_size = int(len(c[0].Steps) * (1 - coef))
  train_data, test_data = c[0].Steps[:split_size], c[0].Steps[split_size:]

  # Normalize the data
  scaler = MinMaxScaler() 
  norm_train = scaler.fit_transform(train_data.to_numpy().reshape(-1, 1))
  norm_test = scaler.transform(test_data.to_numpy().reshape(-1, 1))

  # Prepare
  X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1], c[2])
  X_test, y_test = prepare_sequence(norm_test, c[1], c[2])

  X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

  # Build model
  single_model = simple_RNN(1, X_train.shape[1], X_train.shape[2], c[2])
  # Fit the model
  history = single_model.fit(X_train, y_train, epochs=300, validation_split=0.1, shuffle=False, batch_size=6, callbacks=[early_stopping_cb])

  # Predict
  single_predictions = single_model.predict(X_test)

  rmse = sqrt(mean_squared_error(y_test.squeeze(), single_predictions))
  mae = mean_absolute_error(y_test.squeeze(), single_predictions)
  error_steps = scaler.inverse_transform(np.array(mae).reshape(1, -1))

  results.loc[row] = ["SimpleRNN", "{}_{}".format(c[1], c[2]), mae, rmse, error_steps[0][0]]

  row += 1
# Out:
# Epoch 1/300
# 225/225 [==============================] - 3s 11ms/step - loss: 0.1119 - val_loss: 0.0220
# Epoch 2/300
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0556 - val_loss: 0.0174
# Epoch 3/300
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0418 - val_loss: 0.0187
# Epoch 4/300
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0392 - val_loss: 0.0192
# Epoch 5/300
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0387 - val_loss: 0.0193
# Epoch 6/300
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0387 - val_loss: 0.0192
# Epoch 7/300
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0387 - val_loss: 0.0192
# Epoch 1/300
# 224/224 [==============================] - 5s 17ms/step - loss: 2.3782 - val_loss: 0.1455
# Epoch 2/300
# 224/224 [==============================] - 4s 16ms/step - loss: 0.3598 - val_loss: 0.0393
# Epoch 3/300
# 224/224 [==============================] - 4s 17ms/step - loss: 0.1404 - val_loss: 0.0257
# Epoch 4/300
# 224/224 [==============================] - 4s 16ms/step - loss: 0.0816 - val_loss: 0.0259
# Epoch 5/300
# 224/224 [==============================] - 4s 17ms/step - loss: 0.0610 - val_loss: 0.0273
# Epoch 6/300
# 224/224 [==============================] - 4s 16ms/step - loss: 0.0525 - val_loss: 0.0277
# Epoch 7/300
# 224/224 [==============================] - 4s 16ms/step - loss: 0.0481 - val_loss: 0.0270
# Epoch 8/300
# 224/224 [==============================] - 4s 16ms/step - loss: 0.0452 - val_loss: 0.0260
# Epoch 1/300
# 2742/2742 [==============================] - 73s 26ms/step - loss: 0.0121 - val_loss: 0.0079
# Epoch 2/300
# 2742/2742 [==============================] - 71s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 3/300
# 2742/2742 [==============================] - 72s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 4/300
# 2742/2742 [==============================] - 73s 27ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 5/300
# 2742/2742 [==============================] - 74s 27ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 6/300
# 2742/2742 [==============================] - 73s 27ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 1/300
# 2742/2742 [==============================] - 74s 27ms/step - loss: 0.0122 - val_loss: 0.0079
# Epoch 2/300
# 2742/2742 [==============================] - 72s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 3/300
# 2742/2742 [==============================] - 73s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 4/300
# 2742/2742 [==============================] - 72s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 5/300
# 2742/2742 [==============================] - 74s 27ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 6/300
# 2742/2742 [==============================] - 73s 27ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 1/300
# 2742/2742 [==============================] - 70s 25ms/step - loss: 0.3872 - val_loss: 0.0108
# Epoch 2/300
# 2742/2742 [==============================] - 68s 25ms/step - loss: 0.0167 - val_loss: 0.0084
# Epoch 3/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0122 - val_loss: 0.0080
# Epoch 4/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0113 - val_loss: 0.0079
# Epoch 5/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 6/300
# 2742/2742 [==============================] - 70s 25ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 7/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 8/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0111 - val_loss: 0.0079
# Epoch 9/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0110 - val_loss: 0.0079
# Epoch 10/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 11/300
# 2742/2742 [==============================] - 71s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 12/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 13/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 14/300
# 2742/2742 [==============================] - 70s 25ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 15/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 16/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 17/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 18/300
# 2742/2742 [==============================] - 69s 25ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 19/300
# 2742/2742 [==============================] - 70s 26ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 1/300
# 2738/2738 [==============================] - 137s 50ms/step - loss: 0.2612 - val_loss: 0.0094
# Epoch 2/300
# 2738/2738 [==============================] - 133s 49ms/step - loss: 0.0141 - val_loss: 0.0080
# Epoch 3/300
# 2738/2738 [==============================] - 131s 48ms/step - loss: 0.0115 - val_loss: 0.0079
# Epoch 4/300
# 2738/2738 [==============================] - 130s 47ms/step - loss: 0.0112 - val_loss: 0.0078
# Epoch 5/300
# 2738/2738 [==============================] - 133s 49ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 6/300
# 2738/2738 [==============================] - 130s 47ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 7/300
# 2738/2738 [==============================] - 131s 48ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 8/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 9/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 10/300
# 2738/2738 [==============================] - 133s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 11/300
# 2738/2738 [==============================] - 135s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 12/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 13/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 14/300
# 2738/2738 [==============================] - 135s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 15/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 16/300
# 2738/2738 [==============================] - 134s 49ms/step - loss: 0.0110 - val_loss: 0.0078

# %%
results
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 0       Baseline    7_1  0.109887  0.133907  3545.951198
# 1       Baseline   14_1  0.116042  0.140325  3727.770872
# 2       Baseline   24_1  0.073331  0.094649   620.280473
# 3       Baseline   24_6  0.073325  0.094685   620.230618
# 4       Baseline  24_12  0.073338  0.094732   620.342998
# 5       Baseline  48_24  0.072413  0.095002   612.531287
# 6   Vanilla LSTM    7_1  0.084535  0.112442  2797.085491
# 7   Vanilla LSTM   14_1  0.085292  0.113620  2819.435088
# 8   Vanilla LSTM   24_1  0.072876  0.096130   616.441556
# 9   Vanilla LSTM   24_6  0.072069  0.095411   609.624564
# 10  Vanilla LSTM  24_12  0.072000  0.095288   609.040175
# 11  Vanilla LSTM  48_24  0.071857  0.095206   607.835647
# 12         BLSTM    7_1  0.085940  0.112182  2838.575706
# 13         BLSTM   14_1  0.085001  0.113605  2810.856383
# 14         BLSTM   24_1  0.072937  0.096107   616.956640
# 15         BLSTM   24_6  0.072127  0.095207   610.115911
# 16         BLSTM  24_12  0.072052  0.095196   609.483145
# 17         BLSTM  48_24  0.071808  0.095233   607.421864
# 18     SimpleRNN    7_1  0.086865  0.112112  2865.919571
# 19     SimpleRNN   14_1  0.097181  0.122449  3170.624488
# 20     SimpleRNN   24_1  0.071976  0.095420   608.836776
# 21     SimpleRNN   24_6  0.071964  0.095474   608.736448
# 22     SimpleRNN  24_12  0.072017  0.095469   609.185520
# 23     SimpleRNN  48_24  0.071840  0.095356   607.688238

# %% [markdown]
# ## ConvLSTM

# %%
def Conv_LSTM(n_seq, n_steps, n_features, next_predicted=1):
  model = Sequential()
  model.add(ConvLSTM2D(filters=64, kernel_size=(1,3), activation='tanh', input_shape=(n_seq, 1, n_steps, n_features)))
  model.add(Flatten())
  model.add(Dense(next_predicted))
  model.compile(optimizer='adam', loss='mse')
  return model

# %%
for c in configurations:
  # Split to training and test
  coef = 0.1
  split_size = int(len(c[0].Steps) * (1 - coef))
  train_data, test_data = c[0].Steps[:split_size], c[0].Steps[split_size:]

  # Normalize the data
  scaler = MinMaxScaler() 
  norm_train = scaler.fit_transform(train_data.to_numpy().reshape(-1, 1))
  norm_test = scaler.transform(test_data.to_numpy().reshape(-1, 1))

  # Prepare
  if c[1]%2 != 0:
    X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1]+1, c[2])
    X_test, y_test = prepare_sequence(norm_test, c[1]+1, c[2])
  else:
    X_train, y_train = prepare_sequence(norm_train.tolist()+norm_test.tolist()[:c[2]], c[1], c[2])
    X_test, y_test = prepare_sequence(norm_test, c[1], c[2])

  X_train = X_train.reshape(X_train.shape[0], 2, 1, X_train.shape[1]//2, 1)
  X_test = X_test.reshape(X_test.shape[0], 2, 1, X_test.shape[1]//2, 1)


  # Build model
  single_model = Conv_LSTM(2, X_train.shape[3], X_train.shape[4], c[2])
  # Fit the model
  history = single_model.fit(X_train, y_train, epochs=300, validation_split=0.1, shuffle=False, batch_size=6, callbacks=[early_stopping_cb])

  # Predict
  single_predictions = single_model.predict(X_test)

  rmse = sqrt(mean_squared_error(y_test.squeeze(), single_predictions))
  mae = mean_absolute_error(y_test.squeeze(), single_predictions)
  error_steps = scaler.inverse_transform(np.array(mae).reshape(1, -1))

  results.loc[row] = ["ConvLSTM", "{}_{}".format(c[1], c[2]), mae, rmse, error_steps[0][0]]

  row += 1
# Out:
# Epoch 1/300
# 225/225 [==============================] - 9s 26ms/step - loss: 0.0597 - val_loss: 0.0174
# Epoch 2/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0371 - val_loss: 0.0173
# Epoch 3/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0367 - val_loss: 0.0172
# Epoch 4/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0361 - val_loss: 0.0171
# Epoch 5/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0355 - val_loss: 0.0170
# Epoch 6/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0350 - val_loss: 0.0169
# Epoch 7/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0348 - val_loss: 0.0169
# Epoch 8/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0346 - val_loss: 0.0168
# Epoch 9/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0345 - val_loss: 0.0168
# Epoch 10/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0344 - val_loss: 0.0167
# Epoch 11/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0343 - val_loss: 0.0167
# Epoch 12/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0342 - val_loss: 0.0167
# Epoch 13/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0341 - val_loss: 0.0166
# Epoch 14/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0341 - val_loss: 0.0166
# Epoch 15/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0340 - val_loss: 0.0166
# Epoch 16/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0339 - val_loss: 0.0165
# Epoch 17/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0339 - val_loss: 0.0165
# Epoch 18/300
# 225/225 [==============================] - 5s 22ms/step - loss: 0.0338 - val_loss: 0.0165
# Epoch 19/300
# 225/225 [==============================] - 5s 22ms/step - loss: 0.0338 - val_loss: 0.0165
# Epoch 20/300
# 225/225 [==============================] - 5s 22ms/step - loss: 0.0337 - val_loss: 0.0165
# Epoch 21/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0337 - val_loss: 0.0165
# Epoch 22/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0336 - val_loss: 0.0164
# Epoch 23/300
# 225/225 [==============================] - 5s 24ms/step - loss: 0.0336 - val_loss: 0.0164
# Epoch 24/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0335 - val_loss: 0.0164
# Epoch 25/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0335 - val_loss: 0.0164
# Epoch 26/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0334 - val_loss: 0.0164
# Epoch 27/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0334 - val_loss: 0.0164
# Epoch 28/300
# 225/225 [==============================] - 5s 22ms/step - loss: 0.0334 - val_loss: 0.0164
# Epoch 29/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0333 - val_loss: 0.0164
# Epoch 30/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0333 - val_loss: 0.0164
# Epoch 31/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0332 - val_loss: 0.0164
# Epoch 32/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0332 - val_loss: 0.0164
# Epoch 33/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0332 - val_loss: 0.0164
# Epoch 34/300
# 225/225 [==============================] - 5s 24ms/step - loss: 0.0331 - val_loss: 0.0164
# Epoch 35/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0331 - val_loss: 0.0164
# Epoch 36/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0331 - val_loss: 0.0164
# Epoch 37/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0330 - val_loss: 0.0164
# Epoch 38/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0330 - val_loss: 0.0164
# Epoch 39/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0330 - val_loss: 0.0164
# Epoch 40/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0329 - val_loss: 0.0164
# Epoch 41/300
# 225/225 [==============================] - 5s 23ms/step - loss: 0.0329 - val_loss: 0.0164
# Epoch 1/300
# 224/224 [==============================] - 9s 26ms/step - loss: 0.0513 - val_loss: 0.0171
# Epoch 2/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0319 - val_loss: 0.0173
# Epoch 3/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0320 - val_loss: 0.0173
# Epoch 4/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0318 - val_loss: 0.0172
# Epoch 5/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0316 - val_loss: 0.0171
# Epoch 6/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0314 - val_loss: 0.0170
# Epoch 7/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0313 - val_loss: 0.0169
# Epoch 8/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0311 - val_loss: 0.0169
# Epoch 9/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0310 - val_loss: 0.0168
# Epoch 10/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0308 - val_loss: 0.0168
# Epoch 11/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0307 - val_loss: 0.0167
# Epoch 12/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0306 - val_loss: 0.0167
# Epoch 13/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0305 - val_loss: 0.0167
# Epoch 14/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0304 - val_loss: 0.0166
# Epoch 15/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0303 - val_loss: 0.0166
# Epoch 16/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0302 - val_loss: 0.0166
# Epoch 17/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0302 - val_loss: 0.0166
# Epoch 18/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0301 - val_loss: 0.0166
# Epoch 19/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0300 - val_loss: 0.0166
# Epoch 20/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0299 - val_loss: 0.0165
# Epoch 21/300
# 224/224 [==============================] - 5s 23ms/step - loss: 0.0299 - val_loss: 0.0165
# Epoch 22/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0298 - val_loss: 0.0165
# Epoch 23/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0297 - val_loss: 0.0165
# Epoch 24/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0297 - val_loss: 0.0165
# Epoch 25/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0296 - val_loss: 0.0165
# Epoch 26/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0296 - val_loss: 0.0165
# Epoch 27/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0295 - val_loss: 0.0165
# Epoch 28/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0294 - val_loss: 0.0165
# Epoch 29/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0294 - val_loss: 0.0165
# Epoch 30/300
# 224/224 [==============================] - 5s 24ms/step - loss: 0.0293 - val_loss: 0.0165
# Epoch 1/300
# 2742/2742 [==============================] - 67s 23ms/step - loss: 0.0106 - val_loss: 0.0076
# Epoch 2/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 3/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 4/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 5/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 6/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 7/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 8/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 9/300
# 2742/2742 [==============================] - 64s 24ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 10/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 11/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 12/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 13/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 14/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 15/300
# 2742/2742 [==============================] - 64s 23ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 1/300
# 2742/2742 [==============================] - 66s 23ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 2/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 3/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 4/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 5/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 6/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 7/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 8/300
# 2742/2742 [==============================] - 63s 23ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 9/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 10/300
# 2742/2742 [==============================] - 62s 23ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 1/300
# 2742/2742 [==============================] - 65s 23ms/step - loss: 0.0112 - val_loss: 0.0079
# Epoch 2/300
# 2742/2742 [==============================] - 61s 22ms/step - loss: 0.0108 - val_loss: 0.0079
# Epoch 3/300
# 2742/2742 [==============================] - 61s 22ms/step - loss: 0.0108 - val_loss: 0.0079
# Epoch 4/300
# 2742/2742 [==============================] - 62s 22ms/step - loss: 0.0108 - val_loss: 0.0079
# Epoch 5/300
# 2742/2742 [==============================] - 61s 22ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 6/300
# 2742/2742 [==============================] - 62s 22ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 1/300
# 2738/2738 [==============================] - 67s 24ms/step - loss: 0.0115 - val_loss: 0.0078
# Epoch 2/300
# 2738/2738 [==============================] - 64s 23ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 3/300
# 2738/2738 [==============================] - 64s 23ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 4/300
# 2738/2738 [==============================] - 65s 24ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 5/300
# 2738/2738 [==============================] - 66s 24ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 6/300
# 2738/2738 [==============================] - 65s 24ms/step - loss: 0.0110 - val_loss: 0.0078

# %%
results
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 0       Baseline    7_1  0.109887  0.133907  3545.951198
# 1       Baseline   14_1  0.116042  0.140325  3727.770872
# 2       Baseline   24_1  0.073331  0.094649   620.280473
# 3       Baseline   24_6  0.073325  0.094685   620.230618
# 4       Baseline  24_12  0.073338  0.094732   620.342998
# 5       Baseline  48_24  0.072413  0.095002   612.531287
# 6   Vanilla LSTM    7_1  0.084535  0.112442  2797.085491
# 7   Vanilla LSTM   14_1  0.085292  0.113620  2819.435088
# 8   Vanilla LSTM   24_1  0.072876  0.096130   616.441556
# 9   Vanilla LSTM   24_6  0.072069  0.095411   609.624564
# 10  Vanilla LSTM  24_12  0.072000  0.095288   609.040175
# 11  Vanilla LSTM  48_24  0.071857  0.095206   607.835647
# 12         BLSTM    7_1  0.085940  0.112182  2838.575706
# 13         BLSTM   14_1  0.085001  0.113605  2810.856383
# 14         BLSTM   24_1  0.072937  0.096107   616.956640
# 15         BLSTM   24_6  0.072127  0.095207   610.115911
# 16         BLSTM  24_12  0.072052  0.095196   609.483145
# 17         BLSTM  48_24  0.071808  0.095233   607.421864
# 18     SimpleRNN    7_1  0.086865  0.112112  2865.919571
# 19     SimpleRNN   14_1  0.097181  0.122449  3170.624488
# 20     SimpleRNN   24_1  0.071976  0.095420   608.836776
# 21     SimpleRNN   24_6  0.071964  0.095474   608.736448
# 22     SimpleRNN  24_12  0.072017  0.095469   609.185520
# 23     SimpleRNN  48_24  0.071840  0.095356   607.688238
# 24      ConvLSTM    7_1  0.085792  0.115768  2834.205266
# 25      ConvLSTM   14_1  0.087133  0.117528  2873.817309
# 26      ConvLSTM   24_1  0.073407  0.096179   620.919354
# 27      ConvLSTM   24_6  0.072231  0.095261   610.993724
# 28      ConvLSTM  24_12  0.072004  0.095650   609.070599
# 29      ConvLSTM  48_24  0.071797  0.095584   607.322110

# %% [markdown]
# # Results

# %%
results[results.N_K == "7_1"].sort_values("MAE")
# Out:
#            Model  N_K       MAE      RMSE  Error_Steps
# 6   Vanilla LSTM  7_1  0.084535  0.112442  2797.085491
# 24      ConvLSTM  7_1  0.085792  0.115768  2834.205266
# 12         BLSTM  7_1  0.085940  0.112182  2838.575706
# 18     SimpleRNN  7_1  0.086865  0.112112  2865.919571
# 0       Baseline  7_1  0.109887  0.133907  3545.951198

# %%
results[results.N_K == "14_1"].sort_values("MAE")
# Out:
#            Model   N_K       MAE      RMSE  Error_Steps
# 13         BLSTM  14_1  0.085001  0.113605  2810.856383
# 7   Vanilla LSTM  14_1  0.085292  0.113620  2819.435088
# 25      ConvLSTM  14_1  0.087133  0.117528  2873.817309
# 19     SimpleRNN  14_1  0.097181  0.122449  3170.624488
# 1       Baseline  14_1  0.116042  0.140325  3727.770872

# %%
results[results.N_K == "24_1"].sort_values("MAE")
# Out:
#            Model   N_K       MAE      RMSE  Error_Steps
# 20     SimpleRNN  24_1  0.071976  0.095420   608.836776
# 8   Vanilla LSTM  24_1  0.072876  0.096130   616.441556
# 14         BLSTM  24_1  0.072937  0.096107   616.956640
# 2       Baseline  24_1  0.073331  0.094649   620.280473
# 26      ConvLSTM  24_1  0.073407  0.096179   620.919354

# %%
results[results.N_K == "24_6"].sort_values("MAE")
# Out:
#            Model   N_K       MAE      RMSE  Error_Steps
# 21     SimpleRNN  24_6  0.071964  0.095474   608.736448
# 9   Vanilla LSTM  24_6  0.072069  0.095411   609.624564
# 15         BLSTM  24_6  0.072127  0.095207   610.115911
# 27      ConvLSTM  24_6  0.072231  0.095261   610.993724
# 3       Baseline  24_6  0.073325  0.094685   620.230618

# %%
results[results.N_K == "24_12"].sort_values("MAE")
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 10  Vanilla LSTM  24_12  0.072000  0.095288   609.040175
# 28      ConvLSTM  24_12  0.072004  0.095650   609.070599
# 22     SimpleRNN  24_12  0.072017  0.095469   609.185520
# 16         BLSTM  24_12  0.072052  0.095196   609.483145
# 4       Baseline  24_12  0.073338  0.094732   620.342998

# %%
results[results.N_K == "48_24"].sort_values("MAE")
# Out:
#            Model    N_K       MAE      RMSE  Error_Steps
# 29      ConvLSTM  48_24  0.071797  0.095584   607.322110
# 17         BLSTM  48_24  0.071808  0.095233   607.421864
# 23     SimpleRNN  48_24  0.071840  0.095356   607.688238
# 11  Vanilla LSTM  48_24  0.071857  0.095206   607.835647
# 5       Baseline  48_24  0.072413  0.095002   612.531287

# %%
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
#  ARIMA.ipynb                         dnn.ipynb          StepCountB.csv
#  CL/                                 Experiment.ipynb   StepCount.csv
# 'Copy of Copy of Experiment.ipynb'  'explore t.ipynb'   Test_Notebook.ipynb
# 'Copy of Experiment.ipynb'           LSTM/              Thesis.ipynb

# %%
GIT_TOKEN = "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"
GIT_USERNAME = "MaxBelitsky" 
GIT_REPOSITORY = "step-counts-prediction" 

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# GIT_PATH:  https://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@github.com/MaxBelitsky/step-counts-prediction.git

# %%
# %ls
# Out:
#  ARIMA.ipynb                         Experiment.ipynb   step-counts-prediction/
#  CL/                                'explore t.ipynb'   Test_Notebook.ipynb
# 'Copy of Copy of Experiment.ipynb'   LSTM/              Thesis.ipynb
# 'Copy of Experiment.ipynb'           StepCountB.csv
#  dnn.ipynb                           StepCount.csv

# %%
! git clone "{GIT_PATH}"
# Out:
# Cloning into 'step-counts-prediction'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# %cd step-counts-prediction/
# Out:
# /content/drive/My Drive/Colab Notebooks/step-counts-prediction

# %%
# %ls
# Out:
# 'Copy of Copy of Experiment.ipynb'   README.md   StepCountB.csv   StepCount.csv

# %%
! git branch
# Out:
# * main
